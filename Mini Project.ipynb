# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df = pd.read_csv("D:\\Mini_project.csv")
X_data = df[['Pollution Rate', 'Alchohol and tobacco consumtions', 'UV Rays', 'Genetics and Hormones', 'Infection']]
Y_data = df[['Alpha']]
x_train, x_test, y_train, y_test = train_test_split(X_data, Y_data, test_size=0.2, random_state=1)
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(X_data)

num_in = 5
num_hid = 1  
learning_rate = 0.001
num_out = num_hid

model = Sequential()
model.add(Dense(num_hid, input_dim=num_in, activation='relu'))  
model.add(Dense(num_out, activation=None))  
optimizer = tf.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='mean_squared_error')

epochs = 100
batch_size = 32
model.fit(scaled_data, scaled_data, epochs=epochs, batch_size=batch_size)

output_1d = model.predict(scaled_data)
print(output_1d)


correlation_matrix = df[['Pollution Rate', 'Alchohol and tobacco consumtions', 'UV Rays', 'Genetics and Hormones', 'Infection']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', cbar=True)
plt.title('Correlation Matrix')
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 6ms/step - loss: 1.0429
# Epoch 2/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0133
# Epoch 3/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9849
# Epoch 4/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9567
# Epoch 5/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9304
# Epoch 6/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9049
# Epoch 7/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.8797
# Epoch 8/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8546
# Epoch 9/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8313
# Epoch 10/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8078
# Epoch 11/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7860
# Epoch 12/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7645
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df = pd.read_csv("D:\\Mini_project.csv")
X_data = df[['Chemo', 'Surgery', 'Medicine', 'Healthy living', 'Radiation']]
Y_data = df['Beta']
x_train, x_test, y_train, y_test = train_test_split(X_data, Y_data, test_size=0.2, random_state=1)
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(X_data)

num_in = 5
num_hid = 1  
learning_rate = 0.001
num_out = num_hid

model = Sequential()
model.add(Dense(num_hid, input_dim=num_in, activation='relu'))  
model.add(Dense(num_out, activation=None))  
optimizer = tf.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='mean_squared_error')

epochs = 100
batch_size = 32
model.fit(scaled_data, scaled_data, epochs=epochs, batch_size=batch_size)
output_1d = model.predict(scaled_data)
print(output_1d)

correlation_matrix = df[['Chemo', 'Surgery', 'Medicine', 'Healthy living', 'Radiation']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', cbar=True)
plt.title('Correlation Matrix')
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 3ms/step - loss: 0.6908
# Epoch 2/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6739
# Epoch 3/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6569
# Epoch 4/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6408
# Epoch 5/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6253
# Epoch 6/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6107
# Epoch 7/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5967
# Epoch 8/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5832
# Epoch 9/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5701
# Epoch 10/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5573
# Epoch 11/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5445
# Epoch 12/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5329
# ...
